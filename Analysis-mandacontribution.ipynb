# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewPiasecki/CrimeDataSince2020/blob/main/Analysis-mandacontribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports, Data Info, and Data Cleaning

# %%
import seaborn as sns
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
url = "https://github.com/AndrewPiasecki/CrimeDataSince2020/blob/main/CrimeData.csv?raw=true"

# %%
Crime = pd.read_csv(url, index_col=0)

# %%
Crime.head()
# Out:
#                         Date Rptd                DATE OCC  TIME OCC  AREA  \
# DR_NO
# 190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
#
#            AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# DR_NO
# 190326475   Wilshire          784         1     510
# 200106753    Central          182         1     330
# 200320258  Southwest          356         1     480
# 200907217   Van Nuys          964         1     343
# 220614831  Hollywood          666         2     354
#
#                                         Crm Cd Desc              Mocodes  ...  \
# DR_NO                                                                     ...
# 190326475                          VEHICLE - STOLEN                  NaN  ...
# 200106753                     BURGLARY FROM VEHICLE       1822 1402 0344  ...
# 200320258                             BIKE - STOLEN            0344 1251  ...
# 200907217  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)            0325 1501  ...
# 220614831                         THEFT OF IDENTITY  1822 1501 0930 2004  ...
#
#            Status   Status Desc Crm Cd 1  Crm Cd 2 Crm Cd 3  Crm Cd 4  \
# DR_NO
# 190326475      AA  Adult Arrest    510.0     998.0      NaN       NaN
# 200106753      IC   Invest Cont    330.0     998.0      NaN       NaN
# 200320258      IC   Invest Cont    480.0       NaN      NaN       NaN
# 200907217      IC   Invest Cont    343.0       NaN      NaN       NaN
# 220614831      IC   Invest Cont    354.0       NaN      NaN       NaN
#
#                                            LOCATION Cross Street      LAT  \
# DR_NO
# 190326475   1900 S  LONGWOOD                     AV          NaN  34.0375
# 200106753   1000 S  FLOWER                       ST          NaN  34.0444
# 200320258   1400 W  37TH                         ST          NaN  34.0210
# 200907217  14000    RIVERSIDE                    DR          NaN  34.1576
# 220614831                         1900    TRANSIENT          NaN  34.0944
#
#                 LON
# DR_NO
# 190326475 -118.3506
# 200106753 -118.2628
# 200320258 -118.3002
# 200907217 -118.4387
# 220614831 -118.3277
#
# [5 rows x 27 columns]

# %%
Crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 990293 entries, 190326475 to 240910892
# Data columns (total 27 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Date Rptd       990293 non-null  object
#  1   DATE OCC        990293 non-null  object
#  2   TIME OCC        990293 non-null  int64
#  3   AREA            990293 non-null  int64
#  4   AREA NAME       990293 non-null  object
#  5   Rpt Dist No     990293 non-null  int64
#  6   Part 1-2        990293 non-null  int64
#  7   Crm Cd          990293 non-null  int64
#  8   Crm Cd Desc     990293 non-null  object
#  9   Mocodes         842641 non-null  object
#  10  Vict Age        990293 non-null  int64
#  11  Vict Sex        849515 non-null  object
#  12  Vict Descent    849504 non-null  object
#  13  Premis Cd       989970 non-null  float64
#  14  Premis Desc     989399 non-null  object
#  15  Weapon Used Cd  326547 non-null  float64
#  16  Weapon Desc     326547 non-null  object
#  17  Status          990292 non-null  object
#  18  Status Desc     990293 non-null  object
#  19  Crm Cd 1        990282 non-null  float64
#  20  Crm Cd 2        68957 non-null   float64
#  21  Crm Cd 3        2311 non-null    float64
#  22  Crm Cd 4        64 non-null      float64
#  23  LOCATION        990293 non-null  object
#  24  Cross Street    152641 non-null  object
#  25  LAT             990293 non-null  float64
#  26  LON             990293 non-null  float64
# dtypes: float64(8), int64(6), object(13)
# memory usage: 211.5+ MB

# %%
Crime.isnull().sum()
# Out:
# Date Rptd              0
# DATE OCC               0
# TIME OCC               0
# AREA                   0
# AREA NAME              0
# Rpt Dist No            0
# Part 1-2               0
# Crm Cd                 0
# Crm Cd Desc            0
# Mocodes           147652
# Vict Age               0
# Vict Sex          140778
# Vict Descent      140789
# Premis Cd            323
# Premis Desc          894
# Weapon Used Cd    663746
# Weapon Desc       663746
# Status                 1
# Status Desc            0
# Crm Cd 1              11
# Crm Cd 2          921336
# Crm Cd 3          987982
# Crm Cd 4          990229
# LOCATION               0
# Cross Street      837652
# LAT                    0
# LON                    0
# dtype: int64

# %%
Crime.shape
# Out:
# (990293, 27)

# %%
Crime.describe()
# Out:
#             TIME OCC           AREA    Rpt Dist No       Part 1-2  \
# count  990293.000000  990293.000000  990293.000000  990293.000000
# mean     1339.256672      10.697314    1116.172073       1.402950
# std       651.351436       6.108960     611.015402       0.490491
# min         1.000000       1.000000     101.000000       1.000000
# 25%       900.000000       5.000000     587.000000       1.000000
# 50%      1420.000000      11.000000    1141.000000       1.000000
# 75%      1900.000000      16.000000    1617.000000       2.000000
# max      2359.000000      21.000000    2199.000000       2.000000
#
#               Crm Cd       Vict Age      Premis Cd  Weapon Used Cd  \
# count  990293.000000  990293.000000  989970.000000   326547.000000
# mean      500.675146      29.011584     305.964166      363.873623
# std       205.914118      21.982132     219.200779      123.703129
# min       110.000000      -4.000000     101.000000      101.000000
# 25%       331.000000       0.000000     101.000000      311.000000
# 50%       442.000000      30.000000     203.000000      400.000000
# 75%       626.000000      44.000000     501.000000      400.000000
# max       956.000000     120.000000     976.000000      516.000000
#
#             Crm Cd 1      Crm Cd 2     Crm Cd 3   Crm Cd 4            LAT  \
# count  990282.000000  68957.000000  2311.000000   64.00000  990293.000000
# mean      500.431720    958.159752   984.204673  991.21875      33.986463
# std       205.713105    110.251655    51.485644   27.06985       1.730076
# min       110.000000    210.000000   310.000000  821.00000       0.000000
# 25%       331.000000    998.000000   998.000000  998.00000      34.014600
# 50%       442.000000    998.000000   998.000000  998.00000      34.058900
# 75%       626.000000    998.000000   998.000000  998.00000      34.164900
# max       956.000000    999.000000   999.000000  999.00000      34.334300
#
#                  LON
# count  990293.000000
# mean     -118.050015
# std         5.997837
# min      -118.667600
# 25%      -118.430400
# 50%      -118.322500
# 75%      -118.273900
# max         0.000000

# %%
# Replacing blank values with NA (I parsed through and saw these as the main culprits)

Crime["Status"].fillna("NA", inplace=True)
Crime["Mocodes"].fillna("NA", inplace=True)
Crime["Vict Sex"].fillna("NA", inplace=True)
Crime["Premis Desc"].fillna("NA", inplace=True)
Crime["Premis Cd"].fillna("NA", inplace=True)
Crime["Weapon Used Cd"].fillna("NA", inplace=True)
Crime["Weapon Desc"].fillna("NA", inplace=True)
Crime["Crm Cd 1"].fillna("NA", inplace=True)
Crime["Crm Cd 4"].fillna("NA", inplace=True)
Crime["Crm Cd 3"].fillna("NA", inplace=True)
Crime["Crm Cd 2"].fillna("NA", inplace=True)
Crime["Cross Street"].fillna("NA", inplace=True)
Crime["Vict Descent"].fillna("NA", inplace=True)
# Out:
# <ipython-input-9-04bb5d741786>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Crime["Status"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Crime["Mocodes"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Crime["Vict Sex"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Crime["Premis Desc"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Crime["Premis Cd"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   Crime["Premis Cd"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Crime["Weapon Used Cd"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   Crime["Weapon Used Cd"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Crime["Weapon Desc"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Crime["Crm Cd 1"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   Crime["Crm Cd 1"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Crime["Crm Cd 4"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   Crime["Crm Cd 4"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Crime["Crm Cd 3"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   Crime["Crm Cd 3"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Crime["Crm Cd 2"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   Crime["Crm Cd 2"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Crime["Cross Street"].fillna("NA", inplace=True)
# <ipython-input-9-04bb5d741786>:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Crime["Vict Descent"].fillna("NA", inplace=True)

# %%
# Converting all dates the datetime

Crime[["DATE OCC", "Date Rptd"]].apply(pd.to_datetime)
# Out:
# <ipython-input-10-00f5db8d78b4>:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Crime[["DATE OCC", "Date Rptd"]].apply(pd.to_datetime)
# <ipython-input-10-00f5db8d78b4>:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Crime[["DATE OCC", "Date Rptd"]].apply(pd.to_datetime)
#             DATE OCC  Date Rptd
# DR_NO
# 190326475 2020-03-01 2020-03-01
# 200106753 2020-02-08 2020-02-09
# 200320258 2020-11-04 2020-11-11
# 200907217 2020-03-10 2023-05-10
# 220614831 2020-08-17 2022-08-18
# ...              ...        ...
# 240710284 2024-07-23 2024-07-24
# 240104953 2024-01-15 2024-01-15
# 240410786 2024-10-11 2024-10-14
# 240309674 2024-04-24 2024-04-24
# 240910892 2024-08-12 2024-08-13
#
# [990293 rows x 2 columns]

# %%
Crime.isnull().sum()
# Out:
# Date Rptd         0
# DATE OCC          0
# TIME OCC          0
# AREA              0
# AREA NAME         0
# Rpt Dist No       0
# Part 1-2          0
# Crm Cd            0
# Crm Cd Desc       0
# Mocodes           0
# Vict Age          0
# Vict Sex          0
# Vict Descent      0
# Premis Cd         0
# Premis Desc       0
# Weapon Used Cd    0
# Weapon Desc       0
# Status            0
# Status Desc       0
# Crm Cd 1          0
# Crm Cd 2          0
# Crm Cd 3          0
# Crm Cd 4          0
# LOCATION          0
# Cross Street      0
# LAT               0
# LON               0
# dtype: int64

# %% [markdown]
# # Visualizations and Discovery

# %%
plt.figure(figsize=(20, 7))
sns.countplot(data = Crime, x = "Crm Cd Desc", order = Crime["Crm Cd Desc"].value_counts().index)
plt.xlabel("Crime Type Description")
plt.ylabel("Count")
plt.title("Distribution of Crime Types")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20, 7))
sns.countplot(data=Crime, y='Crm Cd Desc', order=Crime['Crm Cd Desc'].value_counts().head(15).index)
plt.ylabel("Crime Type Description")
plt.xlabel("Count")
plt.title("Distribution of Crime Types (Top 15)")
plt.show()

# %%
top_20_areas = Crime['AREA NAME'].value_counts().nlargest(20).index

# Create an empty dictionary
top_crimes_by_area = {}

# Iterate
for area in top_20_areas:

    area_crimes = Crime[Crime['AREA NAME'] == area]

    top_10_crimes = area_crimes['Crm Cd Desc'].value_counts().nlargest(10)

    top_crimes_by_area[area] = top_10_crimes


top_crimes_df = pd.DataFrame.from_dict(top_crimes_by_area, orient='index').fillna(0)

# Calculate the percentage
top_crimes_percentage_df = top_crimes_df.div(top_crimes_df.sum(axis=1), axis=0) * 100

# Plot
plt.figure(figsize=(15, 10))
top_crimes_percentage_df.plot(kind='bar', stacked=True, figsize=(15, 10))
plt.title('Top 10 Crimes in Top 20 Areas (Percentage)')
plt.xlabel('Area Name')
plt.ylabel('Percentage of Crimes')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Crime Description', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 20 Most Crime Filled Areas

# %%
top_20_areas_df = Crime['AREA NAME'].value_counts().nlargest(20).reset_index()
top_20_areas_df.columns = ['Area Name', 'Crime Count']
top_20_areas_df
# Out:
#       Area Name  Crime Count
# 0       Central        68421
# 1   77th Street        61153
# 2       Pacific        58378
# 3     Southwest        56491
# 4     Hollywood        51726
# 5   N Hollywood        50370
# 6       Olympic        49416
# 7     Southeast        49414
# 8        Newton        48558
# 9      Wilshire        47472
# 10      Rampart        46184
# 11      West LA        45031
# 12    Northeast        42263
# 13     Van Nuys        42245
# 14  West Valley        41584
# 15   Devonshire        41143
# 16       Harbor        40754
# 17      Topanga        40724
# 18      Mission        39754
# 19   Hollenbeck        36455

# %% [markdown]
# ## Count of each Crime that Happened in the 20 most crime filled area

# %%
top_20_crime_counts = {}
for area in top_20_areas:
  area_data = Crime[Crime['AREA NAME'] == area]
  crime_counts = area_data['Crm Cd Desc'].value_counts()
  top_20_crime_counts[area] = crime_counts


top_crimes_df = pd.DataFrame.from_dict(top_20_crime_counts, orient='index')
print("\nCrime Counts for Top 20 Areas:")
top_crimes_df
# Out:
# Crime Counts for Top 20 Areas:
#              BURGLARY FROM VEHICLE  BATTERY - SIMPLE ASSAULT  \
# Central                       9343                      6800
# 77th Street                   1855                      4706
# Pacific                       3880                      3313
# Southwest                     2124                      4520
# Hollywood                     4239                      4481
# N Hollywood                   3529                      3432
# Olympic                       3356                      4380
# Southeast                     1463                      3937
# Newton                        2773                      4156
# Wilshire                      3283                      3162
# Rampart                       2727                      4126
# West LA                       3439                      2829
# Northeast                     3138                      2593
# Van Nuys                      2717                      2847
# West Valley                   2689                      2748
# Devonshire                    2525                      2684
# Harbor                        1675                      3154
# Topanga                       2446                      2764
# Mission                       1828                      2605
# Hollenbeck                    1405                      3091
#
#              VEHICLE - STOLEN  \
# Central                  4887
# 77th Street              8596
# Pacific                  6400
# Southwest                6503
# Hollywood                3918
# N Hollywood              4948
# Olympic                  5594
# Southeast                7069
# Newton                   8109
# Wilshire                 4107
# Rampart                  5315
# West LA                  3405
# Northeast                5246
# Van Nuys                 4560
# West Valley              4195
# Devonshire               3866
# Harbor                   5997
# Topanga                  3386
# Mission                  5895
# Hollenbeck               6069
#
#              VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)  \
# Central                                                   4714
# 77th Street                                               3337
# Pacific                                                   3342
# Southwest                                                 3246
# Hollywood                                                 3468
# N Hollywood                                               3277
# Olympic                                                   3071
# Southeast                                                 2557
# Newton                                                    2917
# Wilshire                                                  2935
# Rampart                                                   2771
# West LA                                                   2856
# Northeast                                                 2816
# Van Nuys                                                  2730
# West Valley                                               2427
# Devonshire                                                2056
# Harbor                                                    2701
# Topanga                                                   2135
# Mission                                                   2258
# Hollenbeck                                                2494
#
#              THEFT PLAIN - PETTY ($950 & UNDER)  \
# Central                                    4209
# 77th Street                                1956
# Pacific                                    4858
# Southwest                                  3012
# Hollywood                                  3821
# N Hollywood                                2739
# Olympic                                    2992
# Southeast                                  1539
# Newton                                     1654
# Wilshire                                   3152
# Rampart                                    2317
# West LA                                    3199
# Northeast                                  2708
# Van Nuys                                   2048
# West Valley                                1842
# Devonshire                                 1962
# Harbor                                     1611
# Topanga                                    2095
# Mission                                    1454
# Hollenbeck                                 1622
#
#              ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  TRESPASSING  \
# Central                                                4044         3227
# 77th Street                                            5912          265
# Pacific                                                2019         1103
# Southwest                                              3626         1066
# Hollywood                                              2738         1369
# N Hollywood                                            1971         1502
# Olympic                                                2673         1001
# Southeast                                              4866          430
# Newton                                                 3760          439
# Wilshire                                               1682          856
# Rampart                                                3094         1333
# West LA                                                 777          917
# Northeast                                              1634          772
# Van Nuys                                               1622          532
# West Valley                                            1773          684
# Devonshire                                             1328          661
# Harbor                                                 2342          452
# Topanga                                                1525          567
# Mission                                                1981          451
# Hollenbeck                                             2335          333
#
#              THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD  \
# Central                                                   2926
# 77th Street                                               1125
# Pacific                                                   3571
# Southwest                                                 1547
# Hollywood                                                 2446
# N Hollywood                                               1987
# Olympic                                                   1553
# Southeast                                                  949
# Newton                                                    1565
# Wilshire                                                  1986
# Rampart                                                   1100
# West LA                                                   2133
# Northeast                                                 1432
# Van Nuys                                                  1292
# West Valley                                               1406
# Devonshire                                                1586
# Harbor                                                    1156
# Topanga                                                   1327
# Mission                                                    972
# Hollenbeck                                                1045
#
#              ROBBERY  BURGLARY  ...  TILL TAP - GRAND THEFT ($950.01 & OVER)  \
# Central         2661      2401  ...                                      NaN
# 77th Street     3804      2167  ...                                      NaN
# Pacific         1094      4423  ...                                      2.0
# Southwest       2013      2109  ...                                      2.0
# Hollywood       2038      2615  ...                                      1.0
# N Hollywood     1130      3719  ...                                      NaN
# Olympic         1838      3096  ...                                      NaN
# Southeast       2628      1375  ...                                      NaN
# Newton          2278      2447  ...                                      3.0
# Wilshire        1520      3704  ...                                      1.0
# Rampart         2052      1844  ...                                      1.0
# West LA          661      4376  ...                                      1.0
# Northeast       1005      2561  ...                                      1.0
# Van Nuys         911      3178  ...                                      NaN
# West Valley      927      3558  ...                                      NaN
# Devonshire       844      3547  ...                                      1.0
# Harbor          1023      2333  ...                                      1.0
# Topanga          931      3183  ...                                      NaN
# Mission         1010      1544  ...                                      NaN
# Hollenbeck      1130      1671  ...                                      2.0
#
#              TELEPHONE PROPERTY - DAMAGE  BRIBERY  \
# Central                              NaN      NaN
# 77th Street                          NaN      NaN
# Pacific                              1.0      NaN
# Southwest                            1.0      1.0
# Hollywood                            NaN      1.0
# N Hollywood                          NaN      NaN
# Olympic                              NaN      NaN
# Southeast                            NaN      1.0
# Newton                               NaN      NaN
# Wilshire                             NaN      NaN
# Rampart                              NaN      NaN
# West LA                              NaN      NaN
# Northeast                            NaN      1.0
# Van Nuys                             NaN      2.0
# West Valley                          1.0      NaN
# Devonshire                           1.0      NaN
# Harbor                               3.0      NaN
# Topanga                              NaN      NaN
# Mission                              NaN      1.0
# Hollenbeck                           NaN      1.0
#
#              BLOCKING DOOR INDUCTION CENTER  \
# Central                                 NaN
# 77th Street                             NaN
# Pacific                                 NaN
# Southwest                               1.0
# Hollywood                               NaN
# N Hollywood                             NaN
# Olympic                                 NaN
# Southeast                               NaN
# Newton                                  NaN
# Wilshire                                NaN
# Rampart                                 NaN
# West LA                                 NaN
# Northeast                               NaN
# Van Nuys                                NaN
# West Valley                             5.0
# Devonshire                              NaN
# Harbor                                  NaN
# Topanga                                 NaN
# Mission                                 NaN
# Hollenbeck                              NaN
#
#              THEFT, COIN MACHINE - GRAND ($950.01 & OVER)  \
# Central                                               NaN
# 77th Street                                           NaN
# Pacific                                               NaN
# Southwest                                             1.0
# Hollywood                                             NaN
# N Hollywood                                           2.0
# Olympic                                               2.0
# Southeast                                             1.0
# Newton                                                NaN
# Wilshire                                              NaN
# Rampart                                               NaN
# West LA                                               1.0
# Northeast                                             NaN
# Van Nuys                                              NaN
# West Valley                                           NaN
# Devonshire                                            2.0
# Harbor                                                1.0
# Topanga                                               NaN
# Mission                                               NaN
# Hollenbeck                                            NaN
#
#              FIREARMS RESTRAINING ORDER (FIREARMS RO)  \
# Central                                           NaN
# 77th Street                                       NaN
# Pacific                                           NaN
# Southwest                                         NaN
# Hollywood                                         1.0
# N Hollywood                                       1.0
# Olympic                                           NaN
# Southeast                                         NaN
# Newton                                            NaN
# Wilshire                                          NaN
# Rampart                                           NaN
# West LA                                           NaN
# Northeast                                         NaN
# Van Nuys                                          NaN
# West Valley                                       NaN
# Devonshire                                        NaN
# Harbor                                            NaN
# Topanga                                           NaN
# Mission                                           1.0
# Hollenbeck                                        NaN
#
#              PETTY THEFT - AUTO REPAIR  DISHONEST EMPLOYEE ATTEMPTED THEFT  \
# Central                            NaN                                 NaN
# 77th Street                        NaN                                 NaN
# Pacific                            NaN                                 NaN
# Southwest                          NaN                                 NaN
# Hollywood                          NaN                                 NaN
# N Hollywood                        3.0                                 1.0
# Olympic                            NaN                                 NaN
# Southeast                          NaN                                 NaN
# Newton                             NaN                                 NaN
# Wilshire                           2.0                                 NaN
# Rampart                            NaN                                 NaN
# West LA                            NaN                                 NaN
# Northeast                          NaN                                 NaN
# Van Nuys                           NaN                                 NaN
# West Valley                        2.0                                 1.0
# Devonshire                         NaN                                 2.0
# Harbor                             1.0                                 NaN
# Topanga                            NaN                                 NaN
# Mission                            NaN                                 NaN
# Hollenbeck                         NaN                                 NaN
#
#              DRUNK ROLL - ATTEMPT  TRAIN WRECKING
# Central                       NaN             NaN
# 77th Street                   NaN             NaN
# Pacific                       NaN             NaN
# Southwest                     NaN             NaN
# Hollywood                     NaN             NaN
# N Hollywood                   NaN             NaN
# Olympic                       NaN             NaN
# Southeast                     1.0             NaN
# Newton                        NaN             NaN
# Wilshire                      NaN             NaN
# Rampart                       NaN             NaN
# West LA                       NaN             NaN
# Northeast                     NaN             NaN
# Van Nuys                      NaN             NaN
# West Valley                   NaN             NaN
# Devonshire                    NaN             NaN
# Harbor                        NaN             1.0
# Topanga                       NaN             NaN
# Mission                       NaN             NaN
# Hollenbeck                    NaN             NaN
#
# [20 rows x 140 columns]

# %% [markdown]
# Principal Component Summary

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

Crime[["DATE OCC", "Date Rptd"]] = Crime[["DATE OCC", "Date Rptd"]].apply(pd.to_datetime)

numerical_features = Crime.select_dtypes(include=np.number).columns
numerical_data = Crime[numerical_features]

scaler = StandardScaler()
scaled_features = scaler.fit_transform(numerical_data)

pc = PCA()
pc.fit(scaled_features)

pc_sum = pd.DataFrame({
    'Standard deviation': np.sqrt(pc.explained_variance_),
    'Proportion of varience': pc.explained_variance_ratio_,
    'Cumulative proportion': np.cumsum(pc.explained_variance_ratio_)

})

pcSummary = pc_sum.transpose()
pcSummary.columns = ['PC{}'.format(i) for i in range(1, len(pcSummary.columns) + 1)]

pcSummary.round(4)
# Out:
# <ipython-input-17-f775c1bd04fa>:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Crime[["DATE OCC", "Date Rptd"]] = Crime[["DATE OCC", "Date Rptd"]].apply(pd.to_datetime)
# <ipython-input-17-f775c1bd04fa>:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Crime[["DATE OCC", "Date Rptd"]] = Crime[["DATE OCC", "Date Rptd"]].apply(pd.to_datetime)
#                            PC1     PC2     PC3     PC4     PC5     PC6  \
# Standard deviation      1.4276  1.4049  1.3087  1.0214  0.9831  0.5132
# Proportion of varience  0.2548  0.2467  0.2141  0.1304  0.1208  0.0329
# Cumulative proportion   0.2548  0.5015  0.7156  0.8460  0.9668  0.9997
#
#                            PC7     PC8
# Standard deviation      0.0386  0.0306
# Proportion of varience  0.0002  0.0001
# Cumulative proportion   0.9999  1.0000

# %%
pcComponents = pd.DataFrame(pc.components_.transpose(),
    columns=pcSummary.columns,
    index=numerical_features)

pcComponents.round(4)
# Out:
#                 PC1     PC2     PC3     PC4     PC5     PC6     PC7     PC8
# TIME OCC     0.0073 -0.0086 -0.0527 -0.6596  0.7477  0.0543 -0.0002  0.0001
# AREA         0.4586  0.5367 -0.0327 -0.0171 -0.0156 -0.0024  0.1082  0.6988
# Rpt Dist No  0.4585  0.5368 -0.0328 -0.0171 -0.0155 -0.0026 -0.1178 -0.6972
# Part 1-2    -0.0858  0.1197  0.6944  0.0138  0.0123  0.7042 -0.0001 -0.0001
# Crm Cd      -0.1001  0.1106  0.6612 -0.2590 -0.1306 -0.6756 -0.0001  0.0000
# Vict Age     0.0070  0.0455  0.1820  0.7049  0.6505 -0.2115 -0.0006  0.0002
# LAT          0.5332 -0.4407  0.1460 -0.0085 -0.0071 -0.0037  0.6981 -0.1131
# LON         -0.5270  0.4482 -0.1462  0.0087  0.0077  0.0035  0.6979 -0.1129

# %% [markdown]
# Principal Component Analysis

# %%
target = Crime['Crm Cd']

pca = PCA(n_components=2)
pca_res = pca.fit_transform(scaled_features)

plt.figure(figsize=(10,6))
plt.scatter(pca_res[:,0], pca_res[:,1], c=target, cmap='viridis', alpha=0.7)

plt.title('PCA')
plt.xlabel('PC1')
plt.ylabel('PC2')

plt.colorbar(label='Offence definition')

plt.grid(True)
plt.show()

# %% [markdown]
# T-Distributed Stochastic Neighbor Embedding (tSNE)

# %%
from sklearn.manifold import TSNE

scaled_features_df = pd.DataFrame(scaled_features, columns=numerical_features)
scaled_features_df = scaled_features_df[0:500]

target = scaled_features_df['Crm Cd']

tsne = TSNE(n_components=2, random_state=42)
tsne_res = tsne.fit_transform(scaled_features_df)

plt.figure(figsize=(10,6))

plt.scatter(tsne_res[:,0], tsne_res[:,1], c=target, cmap='viridis', alpha=0.7)

plt.title('t-SNE')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')

plt.colorbar(label='Offence definition')
plt.grid(True)
plt.show()

# %% [markdown]
# Density-Based Spatial Clustering of Applications (DBSCAN)

# %%
from sklearn.cluster import DBSCAN

scaled_features_df = pd.DataFrame(scaled_features, columns=numerical_features)
scaled_features_df = scaled_features_df[0:500]
X = scaled_features_df[['Crm Cd', 'AREA']]

dbscan = DBSCAN(eps=0.2, min_samples=5)
dbscan.fit(X)

plt.scatter(X['Crm Cd'], X['AREA'], c=dbscan.labels_, cmap='viridis', alpha=0.7)
plt.xlabel("$x_1$")
plt.ylabel("$x_2$", rotation=0)
plt.show()

# %% [markdown]
# K-Means Clustering

# %%
from sklearn.cluster import KMeans

k = KMeans(n_clusters=2, random_state=42)
k.fit(X)

plt.scatter(X['Crm Cd'], X['AREA'], c=k.labels_, s=2)
plt.xlabel("$x_1$")
plt.ylabel("$x_2$", rotation=0)
plt.show()

# %% [markdown]
# Davies Boulding Score (DBI)

# %%
from sklearn.metrics import davies_bouldin_score

X = numerical_data[['Crm Cd', 'AREA']].values
X = X[:500]
# Generate random labels for demonstration (replace with your actual labels if available)
y = np.random.randint(0, 4, size=500)

k_val = []
dbi_val = []

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    labels = kmeans.labels_

    dbi = davies_bouldin_score(X,labels)

    k_val.append(k)
    dbi_val.append(dbi)

import matplotlib.pyplot as plt
plt.plot(k_val, dbi_val, marker='o')
plt.title('DBI for different K')
plt.xlabel('Number of K')
plt.ylabel('DBI')
plt.grid(True)
plt.show()

# %% [markdown]
# Hierachal Clustering : Dendrograms and HeatMap

# %%
from pathlib import Path
from sklearn import preprocessing
from sklearn.metrics import pairwise
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from pandas.plotting import parallel_coordinates

numerical_data.dropna(inplace = True)

crimes = numerical_data[['TIME OCC', 'AREA', 'Rpt Dist No', 'Crm Cd', 'Vict Age']]
crimes = crimes[0:100]
crimes_norm = (crimes - crimes.mean())/crimes.std()

d_norm = pairwise.pairwise_distances(crimes_norm, metric = 'euclidean')
z = linkage(crimes_norm, method = 'single')

fig = plt.figure(figsize=(10, 6))
fig.subplots_adjust(bottom=0.23)
plt.title('Hierarchical Clustering Dendrogram (Single linkage)')
dendrogram(z, labels=crimes_norm.index, color_threshold=1.25)
plt.axhline(y=1.25, color='black', linewidth=0.5, linestyle='dashed')
plt.show()

l = linkage(crimes_norm, method='average')
fig = plt.figure(figsize=(10, 6))
fig.subplots_adjust(bottom=0.23)
plt.title('Hierarchical Clustering Dendrogram (Average linkage)')
dendrogram(l, labels = crimes_norm.index, color_threshold=3)
plt.axhline(y=3, color = 'black', linewidth=0.5, linestyle='dashed')
plt.show()

mem = fcluster(linkage(crimes_norm, 'average'), 6, criterion='maxclust')
mem = pd.Series(mem, index=crimes_norm.index)


crimes_norm.index = ['{}: {}'.format(cluster, AREA) for cluster, AREA in zip(mem, crimes_norm.index)]
sns.clustermap(crimes_norm, method = 'average', col_cluster=False, cmap = "mako_r")
plt.show
# Out:
# <ipython-input-24-7b56e8beef02>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_data.dropna(inplace = True)
# <function matplotlib.pyplot.show(close=None, block=None)>
